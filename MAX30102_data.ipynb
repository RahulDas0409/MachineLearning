# %% [markdown]
# # MAX30102 Data

# %%
import numpy as np
from matplotlib import pyplot as plt
import pandas as pd
import seaborn as sns

# %%
file_path = "G:/Projects/MAX30102/max_data02.csv"
max_data = pd.read_csv(file_path)

# %%
max_data
# Out:
#     Heart Rate Detected  SpO2 Detected  Heart Rate  SpO2
# 0                  True           True          20    99
# 1                  True           True          95    99
# 2                  True           True         194    26
# 3                  True           True         130    81
# 4                  True           True          87    99
# 5                  True           True         105    99
# 6                  True           True          80    99
# 7                  True           True          80    98
# 8                  True          False          95    98
# 9                  True           True          95    99
# 10                 True           True          80    98
# 11                 True           True          68    95
# 12                 True           True          87    98
# 13                 True           True          87    98
# 14                 True           True          63    98
# ...

# %%
sns.set_style("ticks")
plt.figure(figsize=(12,6))
sns.lineplot(data=max_data)
# Out:
# <AxesSubplot:>
